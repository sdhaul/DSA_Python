# %% [markdown]
# <a href="https://colab.research.google.com/github/sdhaul/DSA_Python/blob/main/BasicLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 3.5, 2.8, 4.6, 5.5])

# %%
# Create a linear regression model
model = LinearRegression()

model.fit(X, y)
X_test = np.array([[6],[7], [8], [9]])
predictions = model.predict(X_test)

for i, pred in enumerate(predictions):
  print(f"Predictions for X = {X_test[i][0]}: {pred}")
# Out:
# Predictions for X = 6: 6.109999999999999
# Predictions for X = 7: 6.92
# Predictions for X = 8: 7.7299999999999995
# Predictions for X = 9: 8.54

# %%
plt.scatter(X, y, color='blue', label = 'Data Points')
plt.plot(X_test, predictions, color = 'red', label = 'Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.grid(True)
